# %% [markdown]
# # Memory in Sequence Models
# ## From Forget Gates to KV Caches to State Spaces
#
# **MAT 4953 / MAT 6973 — Mathematical Foundations of AI** (Spring 2026, UTSA)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eduenez/MathAIspring2026UTSA/blob/main/code/sequence_memory_models.ipynb)
#
# ---
#
# Every sequence model must answer the same fundamental question: **how should we compress the history $(x_1, \dots, x_{t-1})$ into a finite representation that is useful for predicting $x_t$?**
#
# Different architectures give different answers, and the mathematical structure of each answer determines the model's capacity, speed, and failure modes:
#
# 1. **RNN hidden state** — a fixed-size vector updated recurrently; suffers from vanishing gradients.
# 2. **LSTM / GRU gates** — learned gates control what to remember and forget; the "constant error carousel" mitigates gradient decay.
# 3. **Transformer KV cache** — explicit storage of all past key-value pairs; perfect recall but $O(T)$ memory and $O(T)$ per-step cost.
# 4. **State-space models (Mamba)** — a structured linear recurrence that can be computed as either an RNN or a convolution; linear scaling in $T$.
#
# **Prerequisites:** Familiarity with RNNs and Transformers from the [Architectures Overview](dnn_architectures_overview.ipynb), and autoregressive generation from the [Generative Models](generative_models.ipynb) lesson.

# %% [markdown]
# ---
# # 0. Setup
#
# This notebook runs on **Google Colab** (GPU/TPU/CPU) and in a **local Jupyter environment** (CPU).
#
# - **Google Colab**: click *Open in Colab* above. Go to *Runtime → Change runtime type* and select
#   **GPU** or **TPU v2** for faster training.
# - **Local**: install dependencies with `pip install -r requirements.txt` from the repository root,
#   then open this file with `jupyter notebook` or `jupyter lab`.
#
# The setup cell below automatically detects the available hardware and configures JAX accordingly.

# %%
# @title Runtime & backend setup (run first)
import os, subprocess, platform

def _detect_platform():
    try:
        import requests
        resp = requests.get(
            'http://metadata.google.internal/computeMetadata/v1/instance/attributes/tpu-name',
            headers={'Metadata-Flavor': 'Google'}, timeout=2)
        if resp.ok:
            return 'tpu'
    except Exception:
        pass
    try:
        result = subprocess.run(
            ['nvidia-smi', '--query-gpu=name', '--format=csv,noheader'],
            capture_output=True, text=True, timeout=5)
        if result.returncode == 0 and result.stdout.strip():
            return 'gpu'
    except Exception:
        pass
    if platform.system() == 'Darwin':
        return 'cpu_macos'
    return 'cpu'

_platform = _detect_platform()
print(f'Platform: {_platform.upper()}')

os.environ['KERAS_BACKEND'] = 'jax'
if _platform == 'tpu':
    pass
elif _platform == 'gpu':
    os.environ['JAX_PLATFORMS'] = 'cuda'
else:
    os.environ['JAX_PLATFORMS'] = 'cpu'

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import FancyArrowPatch, FancyBboxPatch
from matplotlib.lines import Line2D
from IPython.display import display, HTML

import jax
import jax.numpy as jnp
import keras
from keras import layers, ops

# %matplotlib inline
np.random.seed(42)
plt.rcParams.update({'font.size': 12, 'axes.titlesize': 13, 'figure.dpi': 100})

print(f'JAX devices : {jax.devices()}')
print(f'Keras version: {keras.__version__}')
print(f'Keras backend: {keras.backend.backend()}')
# Out:
# Platform: CPU
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# JAX devices : [CpuDevice(id=0)]
# Keras version: 3.13.2
# Keras backend: jax

# %% [markdown]
# ---
# # 1. The Memory Problem
#
# ## 1.1 What does "memory" mean for a sequence model?
#
# Consider a model processing a sequence $(x_1, x_2, \dots, x_T)$. At time step $t$, the model must produce an output based on the history $x_{<t} = (x_1, \dots, x_{t-1})$. The **memory** of the model is the mechanism by which it stores and retrieves information from this history.
#
# There are two fundamental axes along which memory mechanisms differ:
#
# | | **Fixed-size state** | **Growing storage** |
# |---|---|---|
# | **Description** | Compress all history into a vector $\mathbf{h}_t \in \mathbb{R}^d$ of fixed dimension | Store a table of $(\mathbf{k}_i, \mathbf{v}_i)$ pairs that grows with $t$ |
# | **Per-step cost** | $O(d^2)$ (matrix-vector multiply) | $O(t \cdot d)$ (attend over all stored entries) |
# | **Total memory** | $O(d)$ — constant | $O(T \cdot d)$ — linear in sequence length |
# | **Examples** | RNN, LSTM, GRU, SSM/Mamba | Transformer KV cache |
# | **Failure mode** | Lossy compression (forgetting) | Memory and compute blow up for long $T$ |

# %%
# Diagram: the two memory paradigms
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

# --- Left: Fixed-size state (RNN/LSTM/Mamba) ---
ax = axes[0]
ax.set_xlim(-0.5, 5.5); ax.set_ylim(-0.5, 2.5)
ax.set_aspect('equal'); ax.axis('off')
ax.set_title('Fixed-Size State (RNN, LSTM, Mamba)', fontsize=12, fontweight='bold')

for t in range(5):
    # Input
    ax.add_patch(plt.Rectangle((t - 0.2, -0.15), 0.4, 0.3,
                 facecolor='#f9e79f', edgecolor='k', linewidth=0.8))
    ax.text(t, 0, f'$x_{t+1}$', ha='center', va='center', fontsize=9)
    # Hidden state
    ax.add_patch(plt.Rectangle((t - 0.25, 0.75), 0.5, 0.5,
                 facecolor='#aed6f1', edgecolor='k', linewidth=1))
    ax.text(t, 1, f'$\\mathbf{{h}}_{t+1}$', ha='center', va='center', fontsize=9)
    # Arrow: input -> hidden
    ax.annotate('', xy=(t, 0.75), xytext=(t, 0.15),
                arrowprops=dict(arrowstyle='->', color='#555', lw=1.2))
    # Arrow: hidden -> hidden (recurrence)
    if t < 4:
        ax.annotate('', xy=(t + 0.75, 1), xytext=(t + 0.25, 1),
                    arrowprops=dict(arrowstyle='->', color='#e74c3c', lw=2))

ax.text(2.5, 1.6, 'Same-size state passed forward at every step',
        ha='center', fontsize=10, style='italic', color='#e74c3c')

# --- Right: Growing storage (Transformer KV cache) ---
ax = axes[1]
ax.set_xlim(-0.5, 5.5); ax.set_ylim(-0.5, 2.5)
ax.set_aspect('equal'); ax.axis('off')
ax.set_title('Growing Storage (Transformer KV Cache)', fontsize=12, fontweight='bold')

for t in range(5):
    # Input
    ax.add_patch(plt.Rectangle((t - 0.2, -0.15), 0.4, 0.3,
                 facecolor='#f9e79f', edgecolor='k', linewidth=0.8))
    ax.text(t, 0, f'$x_{t+1}$', ha='center', va='center', fontsize=9)
    # KV pair stored
    for s in range(t + 1):
        y_pos = 0.6 + s * 0.35
        ax.add_patch(plt.Rectangle((t - 0.18, y_pos - 0.12), 0.36, 0.24,
                     facecolor='#d5f5e3' if s < t else '#aed6f1',
                     edgecolor='k', linewidth=0.6, alpha=0.8))
    ax.annotate('', xy=(t, 0.48), xytext=(t, 0.15),
                arrowprops=dict(arrowstyle='->', color='#555', lw=1.2))

ax.text(2.5, 2.3, 'Cache grows with each new token',
        ha='center', fontsize=10, style='italic', color='#27ae60')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # 2. LSTM: Gated Memory
#
# ## 2.1 The vanishing gradient problem (recap)
#
# Recall from the [Architectures Overview](dnn_architectures_overview.ipynb) that a simple RNN updates its hidden state by
#
# $$\mathbf{h}_t = \sigma(W_h \mathbf{h}_{t-1} + W_x \mathbf{x}_t + \mathbf{b}).$$
#
# The gradient of the loss at time $T$ with respect to $\mathbf{h}_t$ involves the product
#
# $$\frac{\partial \mathbf{h}_T}{\partial \mathbf{h}_t} = \prod_{s=t+1}^{T} \text{diag}\!\bigl(\sigma'(\cdot)\bigr) \, W_h,$$
#
# which either **vanishes** (if $\|W_h\| < 1$ effectively) or **explodes** (if $\|W_h\| > 1$). This means a simple RNN cannot learn dependencies that span more than $\sim$10–20 time steps.
#
# ## 2.2 The LSTM solution: the constant error carousel
#
# The **Long Short-Term Memory** (Hochreiter & Schmidhuber, 1997) introduces a separate **cell state** $\mathbf{c}_t$ that is updated *additively*:
#
# $$\boxed{\begin{aligned}
# \mathbf{f}_t &= \sigma(W_f [\mathbf{h}_{t-1}, \mathbf{x}_t] + \mathbf{b}_f) && \text{(forget gate)} \\
# \mathbf{i}_t &= \sigma(W_i [\mathbf{h}_{t-1}, \mathbf{x}_t] + \mathbf{b}_i) && \text{(input gate)} \\
# \tilde{\mathbf{c}}_t &= \tanh(W_c [\mathbf{h}_{t-1}, \mathbf{x}_t] + \mathbf{b}_c) && \text{(candidate)} \\
# \mathbf{c}_t &= \mathbf{f}_t \odot \mathbf{c}_{t-1} + \mathbf{i}_t \odot \tilde{\mathbf{c}}_t && \text{(cell update)} \\
# \mathbf{o}_t &= \sigma(W_o [\mathbf{h}_{t-1}, \mathbf{x}_t] + \mathbf{b}_o) && \text{(output gate)} \\
# \mathbf{h}_t &= \mathbf{o}_t \odot \tanh(\mathbf{c}_t) && \text{(hidden state)}
# \end{aligned}}$$
#
# **Why this fixes the gradient:** The cell state update $\mathbf{c}_t = \mathbf{f}_t \odot \mathbf{c}_{t-1} + \dots$ is *additive* — it looks like a residual connection across time. When the forget gate is close to 1, the gradient flows through $\mathbf{c}$ without decay:
#
# $$\frac{\partial \mathbf{c}_T}{\partial \mathbf{c}_t} = \prod_{s=t+1}^{T} \text{diag}(\mathbf{f}_s) \approx I \quad \text{(when } \mathbf{f}_s \approx 1\text{)}.$$
#
# This is the **constant error carousel**: information can persist indefinitely in the cell state as long as the forget gate stays open.

# %%
# Diagram: LSTM cell with gates
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_xlim(-0.5, 5); ax.set_ylim(-0.5, 4.5)
ax.set_aspect('equal'); ax.axis('off')
ax.set_title('LSTM Cell: The Constant Error Carousel', fontsize=14, fontweight='bold')

# Cell state highway (the "carousel")
ax.annotate('', xy=(4.3, 3.5), xytext=(-0.3, 3.5),
            arrowprops=dict(arrowstyle='->', color='#e74c3c', lw=3))
ax.text(2, 3.8, 'Cell state $\\mathbf{c}_{t-1} \\longrightarrow \\mathbf{c}_t$  '
        '(constant error carousel)', ha='center', fontsize=11,
        color='#e74c3c', fontweight='bold')

# Gates
gate_info = [
    (0.8, 2.0, '$\\mathbf{f}_t$\nforget', '#fadbd8'),
    (2.0, 2.0, '$\\mathbf{i}_t$\ninput', '#d5f5e3'),
    (2.0, 1.0, '$\\tilde{\\mathbf{c}}_t$\ncandidate', '#fdebd0'),
    (3.5, 2.0, '$\\mathbf{o}_t$\noutput', '#d6eaf8'),
]
for gx, gy, label, color in gate_info:
    ax.add_patch(FancyBboxPatch((gx - 0.35, gy - 0.35), 0.7, 0.7,
                 boxstyle='round,pad=0.05', facecolor=color,
                 edgecolor='k', linewidth=1.2))
    ax.text(gx, gy, label, ha='center', va='center', fontsize=8, fontweight='bold')

# Multiply symbols on cell state line
for cx, label in [(0.8, '$\\times$'), (2.0, '$+$'), (3.5, '$\\times$')]:
    ax.plot(cx, 3.5, 'o', markersize=16, color='white', markeredgecolor='k',
            markeredgewidth=1.5, zorder=5)
    ax.text(cx, 3.5, label, ha='center', va='center', fontsize=12, zorder=6)

# Arrows from gates to cell state
for gx in [0.8, 2.0, 3.5]:
    ax.annotate('', xy=(gx, 3.2), xytext=(gx, 2.35),
                arrowprops=dict(arrowstyle='->', color='#555', lw=1.2))

# Arrow from candidate to +
ax.annotate('', xy=(2.0, 2.65), xytext=(2.0, 1.35),
            arrowprops=dict(arrowstyle='->', color='#555', lw=1.2, linestyle='--'))

# Input x_t and h_{t-1}
ax.text(-0.3, 0.5, '$[\\mathbf{h}_{t-1},\\, \\mathbf{x}_t]$', fontsize=11,
        ha='center', fontweight='bold',
        bbox=dict(boxstyle='round', facecolor='#f9e79f', edgecolor='k'))
for gx in [0.8, 2.0, 3.5]:
    ax.annotate('', xy=(gx - 0.1, 1.65), xytext=(0.1, 0.7),
                arrowprops=dict(arrowstyle='->', color='#888', lw=0.8,
                                connectionstyle='arc3,rad=0.1'))

# Output h_t
ax.text(4.5, 2.0, '$\\mathbf{h}_t$', fontsize=12, fontweight='bold',
        bbox=dict(boxstyle='round', facecolor='#abebc6', edgecolor='k'))
ax.annotate('', xy=(4.2, 2.0), xytext=(3.85, 2.0),
            arrowprops=dict(arrowstyle='->', color='#555', lw=1.5))

# tanh on output path
ax.annotate('', xy=(3.5, 1.65), xytext=(3.5, 3.2),
            arrowprops=dict(arrowstyle='->', color='#888', lw=0.8, linestyle=':'))
ax.text(3.8, 2.7, 'tanh', fontsize=8, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.3 Experiment: RNN vs. LSTM on long-range memory
#
# We test long-range memory with a **"copy first bit" task**: the model sees a binary sequence and must output the *first* bit at the very end. This requires remembering information across the entire sequence length — a direct test of long-range gradient flow.

# %%
# @title RNN vs LSTM — Sequence Length
hidden_dim = 16     # @param {type: "integer"}
n_epochs_mem = 60   # @param {type: "integer"}

def make_copy_first_data(n, T):
    # Sequence of random bits; label = first bit
    X = np.random.randint(0, 2, (n, T, 1)).astype(np.float32)
    y = X[:, 0, 0]  # first bit
    return X, y

seq_lengths = [10, 25, 50, 100]
results = {}

for T in seq_lengths:
    X_train, y_train = make_copy_first_data(3000, T)
    X_test, y_test = make_copy_first_data(500, T)

    for rnn_type, LayerClass in [('SimpleRNN', layers.SimpleRNN), ('LSTM', layers.LSTM)]:
        model = keras.Sequential([
            layers.Input(shape=(T, 1)),
            LayerClass(hidden_dim),
            layers.Dense(1, activation='sigmoid'),
        ])
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        hist = model.fit(X_train, y_train, epochs=n_epochs_mem, batch_size=64,
                         validation_data=(X_test, y_test), verbose=1)
        results[(rnn_type, T)] = hist.history['val_accuracy'][-1]
        print(f'{rnn_type:>10s}, T={T:3d}: val_acc = {results[(rnn_type, T)]:.3f}')
# Out:
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6520 - loss: 0.6307 - val_accuracy: 0.8580 - val_loss: 0.4963
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.9587 - loss: 0.2940 - val_accuracy: 0.9820 - val_loss: 0.1395
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.9977 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0459
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 1.0000 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 9.7622e-04
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 1.0000 - loss: 9.3698e-04 - val_accuracy: 1.0000 - val_loss: 9.1018e-04
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 1.0000 - loss: 8.7483e-04 - val_accuracy: 1.0000 - val_loss: 8.5074e-04
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 1.0000 - loss: 8.1865e-04 - val_accuracy: 1.0000 - val_loss: 7.9659e-04
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 1.0000 - loss: 7.6757e-04 - val_accuracy: 1.0000 - val_loss: 7.4714e-04
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - accuracy: 1.0000 - loss: 7.2098e-04 - val_accuracy: 1.0000 - val_loss: 7.0259e-04
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 1.0000 - loss: 6.7845e-04 - val_accuracy: 1.0000 - val_loss: 6.6175e-04
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 1.0000 - loss: 6.3949e-04 - val_accuracy: 1.0000 - val_loss: 6.2401e-04
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 1.0000 - loss: 6.0358e-04 - val_accuracy: 1.0000 - val_loss: 5.8951e-04
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 1.0000 - loss: 5.7059e-04 - val_accuracy: 1.0000 - val_loss: 5.5758e-04
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 1.0000 - loss: 5.4011e-04 - val_accuracy: 1.0000 - val_loss: 5.2803e-04
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 1.0000 - loss: 5.1190e-04 - val_accuracy: 1.0000 - val_loss: 5.0061e-04
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 1.0000 - loss: 4.8568e-04 - val_accuracy: 1.0000 - val_loss: 4.7543e-04
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 1.0000 - loss: 4.6141e-04 - val_accuracy: 1.0000 - val_loss: 4.5190e-04
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 1.0000 - loss: 4.3882e-04 - val_accuracy: 1.0000 - val_loss: 4.2976e-04
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 1.0000 - loss: 4.1768e-04 - val_accuracy: 1.0000 - val_loss: 4.0938e-04
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 1.0000 - loss: 3.9801e-04 - val_accuracy: 1.0000 - val_loss: 3.9018e-04
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 1.0000 - loss: 3.7957e-04 - val_accuracy: 1.0000 - val_loss: 3.7227e-04
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 1.0000 - loss: 3.6233e-04 - val_accuracy: 1.0000 - val_loss: 3.5539e-04
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 1.0000 - loss: 3.4612e-04 - val_accuracy: 1.0000 - val_loss: 3.3968e-04
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 1.0000 - loss: 3.3092e-04 - val_accuracy: 1.0000 - val_loss: 3.2483e-04
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 1.0000 - loss: 3.1663e-04 - val_accuracy: 1.0000 - val_loss: 3.1079e-04
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 1.0000 - loss: 3.0314e-04 - val_accuracy: 1.0000 - val_loss: 2.9761e-04
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 1.0000 - loss: 2.9042e-04 - val_accuracy: 1.0000 - val_loss: 2.8527e-04
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 1.0000 - loss: 2.7844e-04 - val_accuracy: 1.0000 - val_loss: 2.7357e-04
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 1.0000 - loss: 2.6711e-04 - val_accuracy: 1.0000 - val_loss: 2.6253e-04
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 1.0000 - loss: 2.5641e-04 - val_accuracy: 1.0000 - val_loss: 2.5194e-04
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 1.0000 - loss: 2.4624e-04 - val_accuracy: 1.0000 - val_loss: 2.4206e-04
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 1.0000 - loss: 2.3665e-04 - val_accuracy: 1.0000 - val_loss: 2.3262e-04
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 1.0000 - loss: 2.2752e-04 - val_accuracy: 1.0000 - val_loss: 2.2368e-04
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 1.0000 - loss: 2.1884e-04 - val_accuracy: 1.0000 - val_loss: 2.1522e-04
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 1.0000 - loss: 2.1061e-04 - val_accuracy: 1.0000 - val_loss: 2.0716e-04
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 1.0000 - loss: 2.0279e-04 - val_accuracy: 1.0000 - val_loss: 1.9947e-04
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 1.0000 - loss: 1.9533e-04 - val_accuracy: 1.0000 - val_loss: 1.9217e-04
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 1.0000 - loss: 1.8823e-04 - val_accuracy: 1.0000 - val_loss: 1.8525e-04
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 1.0000 - loss: 1.8147e-04 - val_accuracy: 1.0000 - val_loss: 1.7859e-04
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 1.0000 - loss: 1.7500e-04 - val_accuracy: 1.0000 - val_loss: 1.7226e-04
#  SimpleRNN, T= 10: val_acc = 1.000
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5547 - loss: 0.6873 - val_accuracy: 0.5260 - val_loss: 0.6781
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.6137 - loss: 0.6474 - val_accuracy: 0.7280 - val_loss: 0.5644
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.8183 - loss: 0.4196 - val_accuracy: 0.8780 - val_loss: 0.2639
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.9487 - loss: 0.1426 - val_accuracy: 1.0000 - val_loss: 0.0357
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 1.0000 - loss: 9.8343e-04 - val_accuracy: 1.0000 - val_loss: 9.4895e-04
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 1.0000 - loss: 9.1939e-04 - val_accuracy: 1.0000 - val_loss: 8.8832e-04
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 1.0000 - loss: 8.6138e-04 - val_accuracy: 1.0000 - val_loss: 8.3316e-04
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 1.0000 - loss: 8.0858e-04 - val_accuracy: 1.0000 - val_loss: 7.8277e-04
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 1.0000 - loss: 7.6035e-04 - val_accuracy: 1.0000 - val_loss: 7.3684e-04
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 1.0000 - loss: 7.1622e-04 - val_accuracy: 1.0000 - val_loss: 6.9465e-04
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 1.0000 - loss: 6.7570e-04 - val_accuracy: 1.0000 - val_loss: 6.5586e-04
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 1.0000 - loss: 6.3838e-04 - val_accuracy: 1.0000 - val_loss: 6.2018e-04
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 1.0000 - loss: 6.0398e-04 - val_accuracy: 1.0000 - val_loss: 5.8716e-04
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 1.0000 - loss: 5.7215e-04 - val_accuracy: 1.0000 - val_loss: 5.5651e-04
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 1.0000 - loss: 5.4263e-04 - val_accuracy: 1.0000 - val_loss: 5.2816e-04
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 1.0000 - loss: 5.1523e-04 - val_accuracy: 1.0000 - val_loss: 5.0178e-04
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 1.0000 - loss: 4.8972e-04 - val_accuracy: 1.0000 - val_loss: 4.7720e-04
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 1.0000 - loss: 4.6594e-04 - val_accuracy: 1.0000 - val_loss: 4.5425e-04
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 1.0000 - loss: 4.4374e-04 - val_accuracy: 1.0000 - val_loss: 4.3283e-04
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 1.0000 - loss: 4.2296e-04 - val_accuracy: 1.0000 - val_loss: 4.1277e-04
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 1.0000 - loss: 4.0351e-04 - val_accuracy: 1.0000 - val_loss: 3.9396e-04
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 1.0000 - loss: 3.8526e-04 - val_accuracy: 1.0000 - val_loss: 3.7630e-04
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 1.0000 - loss: 3.6812e-04 - val_accuracy: 1.0000 - val_loss: 3.5970e-04
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 1.0000 - loss: 3.5199e-04 - val_accuracy: 1.0000 - val_loss: 3.4408e-04
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 1.0000 - loss: 3.3681e-04 - val_accuracy: 1.0000 - val_loss: 3.2936e-04
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 1.0000 - loss: 3.2248e-04 - val_accuracy: 1.0000 - val_loss: 3.1548e-04
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 1.0000 - loss: 3.0897e-04 - val_accuracy: 1.0000 - val_loss: 3.0233e-04
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 1.0000 - loss: 2.9619e-04 - val_accuracy: 1.0000 - val_loss: 2.8993e-04
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 1.0000 - loss: 2.8411e-04 - val_accuracy: 1.0000 - val_loss: 2.7820e-04
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 1.0000 - loss: 2.7267e-04 - val_accuracy: 1.0000 - val_loss: 2.6708e-04
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 1.0000 - loss: 2.6183e-04 - val_accuracy: 1.0000 - val_loss: 2.5655e-04
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 1.0000 - loss: 2.5155e-04 - val_accuracy: 1.0000 - val_loss: 2.4653e-04
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 1.0000 - loss: 2.4179e-04 - val_accuracy: 1.0000 - val_loss: 2.3704e-04
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 1.0000 - loss: 2.3252e-04 - val_accuracy: 1.0000 - val_loss: 2.2800e-04
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 1.0000 - loss: 2.2370e-04 - val_accuracy: 1.0000 - val_loss: 2.1940e-04
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 1.0000 - loss: 2.1531e-04 - val_accuracy: 1.0000 - val_loss: 2.1123e-04
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.0732e-04 - val_accuracy: 1.0000 - val_loss: 2.0347e-04
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 1.0000 - loss: 1.9972e-04 - val_accuracy: 1.0000 - val_loss: 1.9603e-04
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 1.0000 - loss: 1.9246e-04 - val_accuracy: 1.0000 - val_loss: 1.8894e-04
#       LSTM, T= 10: val_acc = 1.000
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5000 - loss: 0.7090 - val_accuracy: 0.5200 - val_loss: 0.6978
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.5953 - loss: 0.6663 - val_accuracy: 0.6980 - val_loss: 0.6205
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.8487 - loss: 0.4505 - val_accuracy: 0.9340 - val_loss: 0.2911
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9823 - loss: 0.1681 - val_accuracy: 1.0000 - val_loss: 0.0913
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 1.0000 - loss: 0.0649 - val_accuracy: 1.0000 - val_loss: 0.0485
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 1.0000 - val_loss: 0.0319
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 9.9660e-04
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 1.0000 - loss: 9.6334e-04 - val_accuracy: 1.0000 - val_loss: 9.4188e-04
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 1.0000 - loss: 9.1270e-04 - val_accuracy: 1.0000 - val_loss: 8.9431e-04
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 1.0000 - loss: 8.6501e-04 - val_accuracy: 1.0000 - val_loss: 8.4881e-04
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 1.0000 - loss: 8.2120e-04 - val_accuracy: 1.0000 - val_loss: 8.0488e-04
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 1.0000 - loss: 7.8000e-04 - val_accuracy: 1.0000 - val_loss: 7.6573e-04
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 1.0000 - loss: 7.4181e-04 - val_accuracy: 1.0000 - val_loss: 7.3033e-04
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 1.0000 - loss: 7.0639e-04 - val_accuracy: 1.0000 - val_loss: 6.9302e-04
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 1.0000 - loss: 6.7295e-04 - val_accuracy: 1.0000 - val_loss: 6.6212e-04
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 1.0000 - loss: 6.4123e-04 - val_accuracy: 1.0000 - val_loss: 6.3011e-04
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 1.0000 - loss: 6.1235e-04 - val_accuracy: 1.0000 - val_loss: 6.0256e-04
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 1.0000 - loss: 5.8436e-04 - val_accuracy: 1.0000 - val_loss: 5.7541e-04
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 1.0000 - loss: 5.5849e-04 - val_accuracy: 1.0000 - val_loss: 5.5062e-04
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 1.0000 - loss: 5.3428e-04 - val_accuracy: 1.0000 - val_loss: 5.2673e-04
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 1.0000 - loss: 5.1108e-04 - val_accuracy: 1.0000 - val_loss: 5.0395e-04
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 1.0000 - loss: 4.8943e-04 - val_accuracy: 1.0000 - val_loss: 4.8272e-04
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 1.0000 - loss: 4.6899e-04 - val_accuracy: 1.0000 - val_loss: 4.6278e-04
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 1.0000 - loss: 4.4959e-04 - val_accuracy: 1.0000 - val_loss: 4.4458e-04
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 1.0000 - loss: 4.3129e-04 - val_accuracy: 1.0000 - val_loss: 4.2609e-04
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.0000 - loss: 4.1391e-04 - val_accuracy: 1.0000 - val_loss: 4.0941e-04
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 1.0000 - loss: 3.9744e-04 - val_accuracy: 1.0000 - val_loss: 3.9348e-04
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 1.0000 - loss: 3.8184e-04 - val_accuracy: 1.0000 - val_loss: 3.7797e-04
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.0000 - loss: 3.6703e-04 - val_accuracy: 1.0000 - val_loss: 3.6369e-04
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 1.0000 - loss: 3.5301e-04 - val_accuracy: 1.0000 - val_loss: 3.4961e-04
#  SimpleRNN, T= 25: val_acc = 1.000
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5043 - loss: 0.6938 - val_accuracy: 0.5100 - val_loss: 0.6928
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4883 - loss: 0.6936 - val_accuracy: 0.5100 - val_loss: 0.6927
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5030 - loss: 0.6933 - val_accuracy: 0.4980 - val_loss: 0.6925
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5053 - loss: 0.6925 - val_accuracy: 0.5320 - val_loss: 0.6914
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5397 - loss: 0.6907 - val_accuracy: 0.5880 - val_loss: 0.6850
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6517 - loss: 0.6258 - val_accuracy: 0.7860 - val_loss: 0.4976
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8290 - loss: 0.3999 - val_accuracy: 0.9060 - val_loss: 0.2521
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9713 - loss: 0.1257 - val_accuracy: 1.0000 - val_loss: 0.0479
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0276
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 9.8712e-04 - val_accuracy: 1.0000 - val_loss: 9.5081e-04
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 9.3544e-04 - val_accuracy: 1.0000 - val_loss: 9.0159e-04
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 8.8757e-04 - val_accuracy: 1.0000 - val_loss: 8.5591e-04
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 8.4312e-04 - val_accuracy: 1.0000 - val_loss: 8.1354e-04
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.0180e-04 - val_accuracy: 1.0000 - val_loss: 7.7412e-04
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.6331e-04 - val_accuracy: 1.0000 - val_loss: 7.3731e-04
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.2737e-04 - val_accuracy: 1.0000 - val_loss: 7.0293e-04
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.9378e-04 - val_accuracy: 1.0000 - val_loss: 6.7080e-04
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.6233e-04 - val_accuracy: 1.0000 - val_loss: 6.4064e-04
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.3283e-04 - val_accuracy: 1.0000 - val_loss: 6.1235e-04
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.0513e-04 - val_accuracy: 1.0000 - val_loss: 5.8578e-04
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.7909e-04 - val_accuracy: 1.0000 - val_loss: 5.6077e-04
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.5456e-04 - val_accuracy: 1.0000 - val_loss: 5.3719e-04
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.3142e-04 - val_accuracy: 1.0000 - val_loss: 5.1498e-04
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.0961e-04 - val_accuracy: 1.0000 - val_loss: 4.9395e-04
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.8898e-04 - val_accuracy: 1.0000 - val_loss: 4.7410e-04
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.6946e-04 - val_accuracy: 1.0000 - val_loss: 4.5530e-04
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.5099e-04 - val_accuracy: 1.0000 - val_loss: 4.3749e-04
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.3349e-04 - val_accuracy: 1.0000 - val_loss: 4.2060e-04
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.1687e-04 - val_accuracy: 1.0000 - val_loss: 4.0459e-04
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.0109e-04 - val_accuracy: 1.0000 - val_loss: 3.8936e-04
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.8610e-04 - val_accuracy: 1.0000 - val_loss: 3.7489e-04
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.7183e-04 - val_accuracy: 1.0000 - val_loss: 3.6111e-04
#       LSTM, T= 25: val_acc = 1.000
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5080 - loss: 0.7107 - val_accuracy: 0.5180 - val_loss: 0.6998
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5080 - loss: 0.6958 - val_accuracy: 0.5060 - val_loss: 0.6980
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5207 - loss: 0.6952 - val_accuracy: 0.5080 - val_loss: 0.6973
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5200 - loss: 0.6937 - val_accuracy: 0.5060 - val_loss: 0.6969
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5190 - loss: 0.6932 - val_accuracy: 0.5140 - val_loss: 0.6959
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5410 - loss: 0.6884 - val_accuracy: 0.6460 - val_loss: 0.6552
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7293 - loss: 0.5523 - val_accuracy: 0.6220 - val_loss: 0.5488
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7157 - loss: 0.5235 - val_accuracy: 0.7760 - val_loss: 0.4884
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7577 - loss: 0.5041 - val_accuracy: 0.6680 - val_loss: 0.5690
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7560 - loss: 0.4828 - val_accuracy: 0.6460 - val_loss: 0.5074
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8100 - loss: 0.3755 - val_accuracy: 0.8300 - val_loss: 0.3570
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8523 - loss: 0.3379 - val_accuracy: 0.8400 - val_loss: 0.3435
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8600 - loss: 0.3232 - val_accuracy: 0.8740 - val_loss: 0.3126
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8860 - loss: 0.2957 - val_accuracy: 0.8760 - val_loss: 0.3005
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8857 - loss: 0.2877 - val_accuracy: 0.8760 - val_loss: 0.2960
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8853 - loss: 0.2840 - val_accuracy: 0.8760 - val_loss: 0.2932
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8867 - loss: 0.2798 - val_accuracy: 0.8760 - val_loss: 0.2911
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8870 - loss: 0.2773 - val_accuracy: 0.8760 - val_loss: 0.2895
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8860 - loss: 0.2766 - val_accuracy: 0.8760 - val_loss: 0.2880
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8867 - loss: 0.2746 - val_accuracy: 0.8800 - val_loss: 0.2824
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8880 - loss: 0.2717 - val_accuracy: 0.8820 - val_loss: 0.2793
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8893 - loss: 0.2693 - val_accuracy: 0.8820 - val_loss: 0.2794
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8890 - loss: 0.2689 - val_accuracy: 0.8740 - val_loss: 0.2869
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8883 - loss: 0.2670 - val_accuracy: 0.8860 - val_loss: 0.2718
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8930 - loss: 0.2621 - val_accuracy: 0.8900 - val_loss: 0.2665
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8940 - loss: 0.2601 - val_accuracy: 0.8900 - val_loss: 0.2659
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8960 - loss: 0.2565 - val_accuracy: 0.8920 - val_loss: 0.2625
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8967 - loss: 0.2548 - val_accuracy: 0.8920 - val_loss: 0.2620
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8973 - loss: 0.2532 - val_accuracy: 0.8920 - val_loss: 0.2616
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8973 - loss: 0.2528 - val_accuracy: 0.8920 - val_loss: 0.2612
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8980 - loss: 0.2518 - val_accuracy: 0.8960 - val_loss: 0.2549
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8563 - loss: 0.3012 - val_accuracy: 0.7680 - val_loss: 0.3896
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7793 - loss: 0.3366 - val_accuracy: 0.7920 - val_loss: 0.2851
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7927 - loss: 0.2953 - val_accuracy: 0.5660 - val_loss: 0.5265
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4207 - loss: 1.1076 - val_accuracy: 0.6560 - val_loss: 0.7584
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7680 - loss: 0.6224 - val_accuracy: 0.8640 - val_loss: 0.5247
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8677 - loss: 0.4809 - val_accuracy: 0.8780 - val_loss: 0.4224
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8717 - loss: 0.4078 - val_accuracy: 0.8800 - val_loss: 0.3669
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8757 - loss: 0.3608 - val_accuracy: 0.8840 - val_loss: 0.3297
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8767 - loss: 0.3357 - val_accuracy: 0.8880 - val_loss: 0.3048
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8780 - loss: 0.3192 - val_accuracy: 0.8880 - val_loss: 0.2947
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8783 - loss: 0.3097 - val_accuracy: 0.8900 - val_loss: 0.2856
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8787 - loss: 0.3031 - val_accuracy: 0.8920 - val_loss: 0.2778
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8800 - loss: 0.2972 - val_accuracy: 0.8940 - val_loss: 0.2712
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8807 - loss: 0.2931 - val_accuracy: 0.8980 - val_loss: 0.2630
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8817 - loss: 0.2895 - val_accuracy: 0.8980 - val_loss: 0.2610
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8823 - loss: 0.2868 - val_accuracy: 0.8980 - val_loss: 0.2594
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8833 - loss: 0.2841 - val_accuracy: 0.8980 - val_loss: 0.2580
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8850 - loss: 0.2805 - val_accuracy: 0.8980 - val_loss: 0.2569
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8853 - loss: 0.2791 - val_accuracy: 0.8980 - val_loss: 0.2558
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8853 - loss: 0.2780 - val_accuracy: 0.8980 - val_loss: 0.2556
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8857 - loss: 0.2767 - val_accuracy: 0.8980 - val_loss: 0.2548
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8857 - loss: 0.2760 - val_accuracy: 0.8980 - val_loss: 0.2541
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8860 - loss: 0.2750 - val_accuracy: 0.8980 - val_loss: 0.2535
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8877 - loss: 0.2725 - val_accuracy: 0.9000 - val_loss: 0.2504
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8887 - loss: 0.2706 - val_accuracy: 0.9000 - val_loss: 0.2499
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8893 - loss: 0.2693 - val_accuracy: 0.9000 - val_loss: 0.2494
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8897 - loss: 0.2679 - val_accuracy: 0.9020 - val_loss: 0.2471
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8903 - loss: 0.2666 - val_accuracy: 0.9020 - val_loss: 0.2468
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8903 - loss: 0.2660 - val_accuracy: 0.9020 - val_loss: 0.2463
#  SimpleRNN, T= 50: val_acc = 0.902
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4927 - loss: 0.6943 - val_accuracy: 0.5220 - val_loss: 0.6928
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5090 - loss: 0.6933 - val_accuracy: 0.5220 - val_loss: 0.6927
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5103 - loss: 0.6933 - val_accuracy: 0.5280 - val_loss: 0.6930
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5120 - loss: 0.6933 - val_accuracy: 0.5220 - val_loss: 0.6926
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6932 - val_accuracy: 0.5220 - val_loss: 0.6926
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6931 - val_accuracy: 0.5220 - val_loss: 0.6927
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4970 - loss: 0.6933 - val_accuracy: 0.5220 - val_loss: 0.6923
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6930 - val_accuracy: 0.5220 - val_loss: 0.6924
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6931 - val_accuracy: 0.5220 - val_loss: 0.6923
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5117 - loss: 0.6929 - val_accuracy: 0.5220 - val_loss: 0.6923
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5117 - loss: 0.6930 - val_accuracy: 0.5220 - val_loss: 0.6923
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6923
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6922
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6921
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5117 - loss: 0.6930 - val_accuracy: 0.5220 - val_loss: 0.6923
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5110 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6921
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6921
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6920
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5093 - loss: 0.6929 - val_accuracy: 0.5240 - val_loss: 0.6921
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6920
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5107 - loss: 0.6929 - val_accuracy: 0.5220 - val_loss: 0.6919
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5143 - loss: 0.6928 - val_accuracy: 0.5120 - val_loss: 0.6921
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4993 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6919
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5117 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6918
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5113 - loss: 0.6927 - val_accuracy: 0.5120 - val_loss: 0.6919
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5143 - loss: 0.6928 - val_accuracy: 0.5160 - val_loss: 0.6919
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5110 - loss: 0.6927 - val_accuracy: 0.5240 - val_loss: 0.6919
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5163 - loss: 0.6931 - val_accuracy: 0.5220 - val_loss: 0.6918
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5110 - loss: 0.6928 - val_accuracy: 0.5300 - val_loss: 0.6920
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5093 - loss: 0.6928 - val_accuracy: 0.5160 - val_loss: 0.6918
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5120 - loss: 0.6927 - val_accuracy: 0.5200 - val_loss: 0.6918
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5167 - loss: 0.6930 - val_accuracy: 0.5200 - val_loss: 0.6918
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5100 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6916
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5157 - loss: 0.6927 - val_accuracy: 0.5100 - val_loss: 0.6919
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5207 - loss: 0.6926 - val_accuracy: 0.5240 - val_loss: 0.6917
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 0.6927 - val_accuracy: 0.5300 - val_loss: 0.6917
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5130 - loss: 0.6926 - val_accuracy: 0.5240 - val_loss: 0.6919
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5227 - loss: 0.6925 - val_accuracy: 0.5320 - val_loss: 0.6914
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5883 - loss: 0.6685 - val_accuracy: 0.7880 - val_loss: 0.5380
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8817 - loss: 0.3278 - val_accuracy: 1.0000 - val_loss: 0.0969
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0539 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
#       LSTM, T= 50: val_acc = 1.000
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5203 - loss: 0.7078 - val_accuracy: 0.5140 - val_loss: 0.6940
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5243 - loss: 0.6959 - val_accuracy: 0.5220 - val_loss: 0.6915
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5287 - loss: 0.6939 - val_accuracy: 0.5200 - val_loss: 0.6915
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5220 - loss: 0.6931 - val_accuracy: 0.5140 - val_loss: 0.6920
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5180 - loss: 0.6926 - val_accuracy: 0.5240 - val_loss: 0.6917
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5230 - loss: 0.6924 - val_accuracy: 0.5280 - val_loss: 0.6919
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5230 - loss: 0.6921 - val_accuracy: 0.5300 - val_loss: 0.6922
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5240 - loss: 0.6916 - val_accuracy: 0.5240 - val_loss: 0.6922
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5297 - loss: 0.6920 - val_accuracy: 0.5320 - val_loss: 0.6921
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5233 - loss: 0.6914 - val_accuracy: 0.5240 - val_loss: 0.6923
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5263 - loss: 0.6914 - val_accuracy: 0.5260 - val_loss: 0.6925
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5237 - loss: 0.6911 - val_accuracy: 0.5160 - val_loss: 0.6926
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5127 - loss: 0.6914 - val_accuracy: 0.5240 - val_loss: 0.6927
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5293 - loss: 0.6908 - val_accuracy: 0.5100 - val_loss: 0.6928
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5203 - loss: 0.6907 - val_accuracy: 0.5060 - val_loss: 0.6924
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6870 - loss: 0.5901 - val_accuracy: 0.9200 - val_loss: 0.3846
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.2195 - val_accuracy: 0.9960 - val_loss: 0.1258
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0555
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0425 - val_accuracy: 1.0000 - val_loss: 0.0321
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 1.0000 - val_loss: 0.0218
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 9.6430e-04
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.6685e-04 - val_accuracy: 1.0000 - val_loss: 9.1974e-04
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.1612e-04 - val_accuracy: 1.0000 - val_loss: 8.7325e-04
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.7773e-04 - val_accuracy: 1.0000 - val_loss: 8.3824e-04
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.3405e-04 - val_accuracy: 1.0000 - val_loss: 7.9131e-04
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.9038e-04 - val_accuracy: 1.0000 - val_loss: 7.5593e-04
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.5784e-04 - val_accuracy: 1.0000 - val_loss: 7.1772e-04
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.1991e-04 - val_accuracy: 1.0000 - val_loss: 6.8857e-04
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.9002e-04 - val_accuracy: 1.0000 - val_loss: 6.5724e-04
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.5930e-04 - val_accuracy: 1.0000 - val_loss: 6.3480e-04
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.3354e-04 - val_accuracy: 1.0000 - val_loss: 6.0236e-04
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.0361e-04 - val_accuracy: 1.0000 - val_loss: 5.7701e-04
#  SimpleRNN, T=100: val_acc = 1.000
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5053 - loss: 0.6956 - val_accuracy: 0.5020 - val_loss: 0.6942
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4880 - loss: 0.6938 - val_accuracy: 0.4940 - val_loss: 0.6939
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4950 - loss: 0.6937 - val_accuracy: 0.4840 - val_loss: 0.6940
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4930 - loss: 0.6935 - val_accuracy: 0.4860 - val_loss: 0.6936
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4943 - loss: 0.6936 - val_accuracy: 0.4700 - val_loss: 0.6941
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5007 - loss: 0.6935 - val_accuracy: 0.4780 - val_loss: 0.6939
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4990 - loss: 0.6934 - val_accuracy: 0.4740 - val_loss: 0.6940
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4977 - loss: 0.6934 - val_accuracy: 0.4800 - val_loss: 0.6935
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4957 - loss: 0.6934 - val_accuracy: 0.4580 - val_loss: 0.6937
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5050 - loss: 0.6935 - val_accuracy: 0.4600 - val_loss: 0.6937
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4917 - loss: 0.6933 - val_accuracy: 0.5080 - val_loss: 0.6933
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4990 - loss: 0.6932 - val_accuracy: 0.4620 - val_loss: 0.6936
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5030 - loss: 0.6935 - val_accuracy: 0.4580 - val_loss: 0.6935
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4860 - loss: 0.6933 - val_accuracy: 0.4780 - val_loss: 0.6934
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.4660 - val_loss: 0.6935
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4953 - loss: 0.6931 - val_accuracy: 0.4780 - val_loss: 0.6937
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5020 - loss: 0.6931 - val_accuracy: 0.4760 - val_loss: 0.6935
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4960 - loss: 0.6932 - val_accuracy: 0.4880 - val_loss: 0.6938
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4940 - loss: 0.6933 - val_accuracy: 0.4880 - val_loss: 0.6937
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5040 - loss: 0.6932 - val_accuracy: 0.4840 - val_loss: 0.6938
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5033 - loss: 0.6932 - val_accuracy: 0.4760 - val_loss: 0.6937
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4933 - loss: 0.6932 - val_accuracy: 0.5020 - val_loss: 0.6935
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5067 - loss: 0.6931 - val_accuracy: 0.4720 - val_loss: 0.6937
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5047 - loss: 0.6931 - val_accuracy: 0.4780 - val_loss: 0.6941
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4977 - loss: 0.6931 - val_accuracy: 0.4800 - val_loss: 0.6939
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5077 - loss: 0.6931 - val_accuracy: 0.4800 - val_loss: 0.6938
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5060 - loss: 0.6932 - val_accuracy: 0.4860 - val_loss: 0.6942
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5093 - loss: 0.6930 - val_accuracy: 0.4920 - val_loss: 0.6938
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.4900 - val_loss: 0.6939
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5063 - loss: 0.6932 - val_accuracy: 0.4860 - val_loss: 0.6939
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5150 - loss: 0.6929 - val_accuracy: 0.4720 - val_loss: 0.6943
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4970 - loss: 0.6932 - val_accuracy: 0.4880 - val_loss: 0.6944
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5023 - loss: 0.6931 - val_accuracy: 0.4780 - val_loss: 0.6945
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5080 - loss: 0.6928 - val_accuracy: 0.4760 - val_loss: 0.6945
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5030 - loss: 0.6929 - val_accuracy: 0.4720 - val_loss: 0.6948
# Epoch 36/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5023 - loss: 0.6930 - val_accuracy: 0.4740 - val_loss: 0.6957
# Epoch 37/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5083 - loss: 0.6928 - val_accuracy: 0.4280 - val_loss: 0.6957
# Epoch 38/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5153 - loss: 0.6928 - val_accuracy: 0.4480 - val_loss: 0.6958
# Epoch 39/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5080 - loss: 0.6926 - val_accuracy: 0.4580 - val_loss: 0.6969
# Epoch 40/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5213 - loss: 0.6926 - val_accuracy: 0.4440 - val_loss: 0.6969
# Epoch 41/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5960 - loss: 0.6637 - val_accuracy: 0.7300 - val_loss: 0.5987
# Epoch 42/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8073 - loss: 0.4658 - val_accuracy: 0.8860 - val_loss: 0.3465
# Epoch 43/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9500 - loss: 0.2034 - val_accuracy: 0.9840 - val_loss: 0.1047
# Epoch 44/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9970 - loss: 0.0642 - val_accuracy: 1.0000 - val_loss: 0.0390
# Epoch 45/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0180
# Epoch 46/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 47/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 48/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 49/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 50/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 51/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 52/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 53/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 54/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 55/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 56/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 57/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 58/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 59/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 60/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
#       LSTM, T=100: val_acc = 1.000

# %%
# Plot: accuracy vs. sequence length for RNN vs. LSTM
fig, ax = plt.subplots(figsize=(9, 5))

rnn_accs = [results[('SimpleRNN', T)] for T in seq_lengths]
lstm_accs = [results[('LSTM', T)] for T in seq_lengths]

ax.plot(seq_lengths, rnn_accs, 'o-', color='#e74c3c', linewidth=2.5,
        markersize=10, label='SimpleRNN', markeredgecolor='k', markeredgewidth=0.5)
ax.plot(seq_lengths, lstm_accs, 's-', color='#3498db', linewidth=2.5,
        markersize=10, label='LSTM', markeredgecolor='k', markeredgewidth=0.5)
ax.axhline(0.5, color='gray', linestyle=':', linewidth=1, label='Random baseline')
ax.axhline(1.0, color='gray', linestyle='--', linewidth=0.8, alpha=0.5)

ax.set_xlabel('Sequence Length $T$', fontsize=12)
ax.set_ylabel('Validation Accuracy', fontsize=12)
ax.set_title('"Copy First Bit" Task: Long-Range Memory', fontweight='bold')
ax.legend(fontsize=11); ax.grid(True, alpha=0.3)
ax.set_ylim(0.4, 1.05)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** The SimpleRNN collapses to random-guess accuracy ($\approx 0.5$) as the sequence length grows beyond ~25, while the LSTM maintains near-perfect accuracy even for $T = 100$. This is the constant error carousel in action: the forget gate can hold the first bit in the cell state $\mathbf{c}_t$ indefinitely.
#
# **Experiment:**
# - Reduce `hidden_dim` to 4 or 2. How small can the LSTM be and still solve this task? (Hint: it only needs to store one bit.)
# - Try replacing `LSTM` with `GRU` (Gated Recurrent Unit). The GRU merges the forget and input gates into a single "update gate" — does it perform comparably?

# %% [markdown]
# ---
# # 3. Transformer Memory: The KV Cache
#
# ## 3.1 Attention as a soft dictionary lookup
#
# Recall the self-attention mechanism from the [Architectures Overview](dnn_architectures_overview.ipynb):
#
# $$\text{Attention}(Q, K, V) = \text{softmax}\!\left(\frac{QK^\top}{\sqrt{d_k}}\right) V.$$
#
# We can reinterpret this as a **soft dictionary lookup**:
#
# - Each past token $x_s$ stores a **key** $\mathbf{k}_s$ and a **value** $\mathbf{v}_s$ in memory.
# - The current token produces a **query** $\mathbf{q}_t$.
# - The output is a *weighted average* of stored values, with weights proportional to the query-key similarity:
#
# $$\text{output}_t = \sum_{s=1}^{t} \alpha_{t,s} \, \mathbf{v}_s, \qquad \alpha_{t,s} = \frac{\exp(\mathbf{q}_t \cdot \mathbf{k}_s / \sqrt{d_k})}{\sum_{s'=1}^{t} \exp(\mathbf{q}_t \cdot \mathbf{k}_{s'} / \sqrt{d_k})}.$$
#
# ## 3.2 The KV cache during generation
#
# During **autoregressive generation** (see [Generative Models](generative_models.ipynb)), the model generates one token at a time. Without caching, generating token $t$ would require recomputing the keys and values for *all* previous tokens — $O(t \cdot d)$ work per step, $O(T^2 d)$ total.
#
# The **KV cache** stores all previously computed $(\mathbf{k}_s, \mathbf{v}_s)$ pairs, so each new step only needs to:
# 1. Compute $\mathbf{q}_t, \mathbf{k}_t, \mathbf{v}_t$ for the *new* token (one forward pass through the projection layers).
# 2. Append $\mathbf{k}_t, \mathbf{v}_t$ to the cache.
# 3. Compute attention over the full cache.
#
# | | Without KV cache | With KV cache |
# |---|---|---|
# | Work per new token | $O(t \cdot d)$ (recompute all K, V) | $O(d^2 + t \cdot d)$ (project new token + attend) |
# | Memory | $O(d)$ | $O(T \cdot d)$ per layer |
# | Total to generate $T$ tokens | $O(T^2 \cdot d)$ | $O(T^2 \cdot d)$ attention + $O(T \cdot d^2)$ projections |
#
# The KV cache trades **memory** for **compute**: it avoids redundant recomputation at the cost of storing all past keys and values. For a model with $L$ layers, $H$ attention heads, and key dimension $d_k$, the cache for a sequence of length $T$ requires $2 \times L \times H \times T \times d_k$ floating-point numbers.

# %%
# Interactive: visualize the KV cache growing during generation
# We manually compute attention step-by-step to show the cache

d_model = 8
d_k = 4
T_gen = 8  # number of tokens to "generate"

np.random.seed(7)
# Simulated token embeddings (pretend these come from an embedding layer)
X_tokens = np.random.randn(T_gen, d_model).astype(np.float32)

# Projection matrices
W_Q = np.random.randn(d_model, d_k).astype(np.float32) * 0.3
W_K = np.random.randn(d_model, d_k).astype(np.float32) * 0.3
W_V = np.random.randn(d_model, d_k).astype(np.float32) * 0.3

# Step-by-step generation with KV cache
K_cache = []
V_cache = []
attention_maps = []

for t in range(T_gen):
    q_t = X_tokens[t] @ W_Q  # query for new token
    k_t = X_tokens[t] @ W_K  # key for new token
    v_t = X_tokens[t] @ W_V  # value for new token

    K_cache.append(k_t)
    V_cache.append(v_t)

    K_mat = np.array(K_cache)  # (t+1, d_k)
    scores = (q_t @ K_mat.T) / np.sqrt(d_k)  # (t+1,)
    attn = np.exp(scores - scores.max())
    attn = attn / attn.sum()
    attention_maps.append(attn)

# Visualize: attention pattern at each generation step
fig, axes = plt.subplots(2, 4, figsize=(16, 7))
axes = axes.flatten()

for t in range(T_gen):
    ax = axes[t]
    attn = attention_maps[t]
    bars = ax.bar(range(len(attn)), attn, color='#3498db', edgecolor='k', linewidth=0.5)
    # Highlight the newest key (self-attention to current token)
    bars[-1].set_color('#e74c3c')
    ax.set_xlim(-0.5, T_gen - 0.5)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(T_gen))
    ax.set_xticklabels([f'$k_{s}$' if s <= t else '' for s in range(T_gen)], fontsize=8)
    ax.set_title(f'Step {t+1}: query $q_{t}$', fontsize=10, fontweight='bold')
    ax.grid(True, alpha=0.3, axis='y')
    # Show cache size
    ax.text(0.98, 0.92, f'cache: {t+1} entries', transform=ax.transAxes,
            ha='right', fontsize=8, style='italic',
            bbox=dict(boxstyle='round', facecolor='#fdebd0', alpha=0.8))

plt.suptitle('KV Cache: Attention Weights During Autoregressive Generation',
             fontweight='bold', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()
print(f'Final KV cache size: {T_gen} entries × {d_k} dimensions = {T_gen * d_k} floats (×2 for K and V)')
# Out:
# Final KV cache size: 8 entries × 4 dimensions = 32 floats (×2 for K and V)

# %% [markdown]
# **Key takeaway:** The KV cache gives the Transformer **perfect recall** of all past tokens — at any step $t$, it can attend to any previous position with equal ease. This is fundamentally different from an RNN, which must compress everything into a fixed-size vector.
#
# The price is **linear memory growth**: for long contexts (e.g., $T = 100{,}000$ tokens), the KV cache can consume tens of gigabytes of GPU memory. This motivates the search for alternatives that scale better.

# %%
# Visualize: memory and compute scaling comparison
T_range = np.arange(1, 201)
d = 64  # model dimension (for illustration)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Memory
axes[0].plot(T_range, np.full_like(T_range, d, dtype=float), '--',
             color='#e74c3c', linewidth=2, label='RNN/LSTM ($O(d)$, constant)')
axes[0].plot(T_range, T_range * d, '-',
             color='#3498db', linewidth=2, label='Transformer KV ($O(Td)$, linear)')
axes[0].plot(T_range, np.full_like(T_range, d, dtype=float) * 4, ':',
             color='#2ecc71', linewidth=2, label='SSM/Mamba ($O(d)$, constant)')
axes[0].set_xlabel('Sequence Length $T$'); axes[0].set_ylabel('Memory (arbitrary units)')
axes[0].set_title('Memory Footprint', fontweight='bold')
axes[0].legend(fontsize=9); axes[0].grid(True, alpha=0.3)

# Per-step compute
axes[1].plot(T_range, np.full_like(T_range, d**2, dtype=float), '--',
             color='#e74c3c', linewidth=2, label='RNN/LSTM ($O(d^2)$)')
axes[1].plot(T_range, T_range * d, '-',
             color='#3498db', linewidth=2, label='Transformer ($O(Td)$)')
axes[1].plot(T_range, np.full_like(T_range, d**2, dtype=float) * 1.2, ':',
             color='#2ecc71', linewidth=2, label='SSM/Mamba ($O(d^2)$)')
axes[1].set_xlabel('Sequence Length $T$'); axes[1].set_ylabel('FLOPs per new token')
axes[1].set_title('Per-Step Compute', fontweight='bold')
axes[1].legend(fontsize=9); axes[1].grid(True, alpha=0.3)

plt.suptitle('Scaling: Memory and Compute vs. Sequence Length', fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # 4. State-Space Models and Mamba
#
# ## 4.1 Linear state-space models (SSMs)
#
# A **structured state-space model** (Gu et al., 2021) defines a linear recurrence in continuous time, then discretizes it:
#
# $$\begin{aligned}
# \text{Continuous:} \quad \dot{\mathbf{h}}(t) &= A\,\mathbf{h}(t) + B\,x(t), \quad y(t) = C\,\mathbf{h}(t), \\
# \text{Discrete:} \quad \mathbf{h}_t &= \bar{A}\,\mathbf{h}_{t-1} + \bar{B}\,x_t, \quad y_t = C\,\mathbf{h}_t,
# \end{aligned}$$
#
# where $\bar{A}, \bar{B}$ are obtained by discretizing the continuous parameters with a step size $\Delta$.
#
# **The dual view** is the key mathematical insight:
#
# $$\boxed{\text{Recurrence: } \mathbf{h}_t = \bar{A}\mathbf{h}_{t-1} + \bar{B}x_t \quad \Longleftrightarrow \quad \text{Convolution: } y = K * x, \text{ where } K_t = C\bar{A}^t\bar{B}.}$$
#
# - **Recurrence mode** (like an RNN): process one token at a time with $O(d)$ memory and $O(d^2)$ per-step cost. Ideal for **generation**.
# - **Convolution mode** (like a CNN): process the entire sequence in parallel with a precomputed kernel $K$. Ideal for **training**.
#
# This duality means SSMs get the **best of both worlds**: parallel training like a Transformer and constant-memory inference like an RNN.
#
# ## 4.2 Mamba: selective state spaces
#
# The limitation of linear SSMs is that $\bar{A}$ and $\bar{B}$ are **fixed** (input-independent), so the model cannot decide *what* to remember based on the content. **Mamba** (Gu & Dao, 2023) makes the parameters input-dependent:
#
# $$\bar{B}_t = \bar{B}(x_t), \quad \bar{C}_t = \bar{C}(x_t), \quad \Delta_t = \Delta(x_t).$$
#
# This "**selection mechanism**" breaks the convolution equivalence (since the kernel now depends on the input), but Mamba uses a hardware-efficient parallel scan algorithm to maintain near-linear training speed.
#
# The intuition: Mamba's input-dependent $\Delta_t$ acts like a **learned gate** — when $\Delta_t$ is large, the model "lets in" new information; when $\Delta_t$ is small, it retains the old state. This is conceptually similar to the LSTM's input gate, but implemented through the discretization step size.

# %%
# Demonstrate the recurrence ↔ convolution duality with a toy SSM

# Define a simple 1-D SSM
state_dim = 4
A_cont = -np.eye(state_dim) * 0.5 + np.diag(np.ones(state_dim - 1) * 0.3, 1)  # stable A
B_cont = np.random.randn(state_dim, 1).astype(np.float32) * 0.5
C_cont = np.random.randn(1, state_dim).astype(np.float32) * 0.5
Delta = 0.1  # discretization step

# Discretize: zero-order hold
A_bar = np.eye(state_dim) + Delta * A_cont  # Euler approximation
B_bar = Delta * B_cont

# Generate a random input sequence
T_ssm = 50
x_input = np.random.randn(T_ssm).astype(np.float32)

# --- Method 1: Recurrence ---
h = np.zeros(state_dim, dtype=np.float32)
y_recurrence = np.zeros(T_ssm, dtype=np.float32)
for t in range(T_ssm):
    h = A_bar @ h + B_bar.flatten() * x_input[t]
    y_recurrence[t] = (C_cont @ h).item()

# --- Method 2: Convolution ---
# Compute kernel K_t = C * A_bar^t * B_bar
K_kernel = np.zeros(T_ssm, dtype=np.float32)
A_power = np.eye(state_dim)
for t in range(T_ssm):
    K_kernel[t] = (C_cont @ A_power @ B_bar).item()
    A_power = A_power @ A_bar

y_convolution = np.convolve(x_input, K_kernel)[:T_ssm]

# Plot
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].stem(range(min(20, T_ssm)), K_kernel[:20], linefmt='steelblue',
             markerfmt='o', basefmt=' ')
axes[0].set_xlabel('$t$'); axes[0].set_ylabel('$K_t$')
axes[0].set_title('SSM Kernel $K_t = C\\bar{A}^t\\bar{B}$', fontweight='bold')
axes[0].grid(True, alpha=0.3)

axes[1].plot(y_recurrence, color='#e74c3c', linewidth=2, label='Recurrence')
axes[1].plot(y_convolution, '--', color='#3498db', linewidth=2, label='Convolution')
axes[1].set_xlabel('$t$'); axes[1].set_ylabel('$y_t$')
axes[1].set_title('Output: Recurrence vs. Convolution', fontweight='bold')
axes[1].legend(); axes[1].grid(True, alpha=0.3)

diff = np.abs(y_recurrence - y_convolution)
axes[2].semilogy(diff + 1e-16, color='#2ecc71', linewidth=2)
axes[2].set_xlabel('$t$'); axes[2].set_ylabel('$|y_{\\text{rec}} - y_{\\text{conv}}|$')
axes[2].set_title('Numerical Difference (should be ≈ 0)', fontweight='bold')
axes[2].grid(True, alpha=0.3)

plt.suptitle('SSM Duality: Same Output, Two Computation Modes', fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
print(f'Max difference: {diff.max():.2e} (numerical precision)')
# Out:
# Max difference: 1.49e-08 (numerical precision)

# %% [markdown]
# ## 4.3 Selective gating: from linear SSM to Mamba
#
# The plot below illustrates the key difference between a fixed-parameter SSM and Mamba's selective mechanism. In a standard SSM, the dynamics matrix $\bar{A}$ treats every input identically. In Mamba, the step size $\Delta_t$ adapts to the input, allowing the model to selectively **gate** information.
#
# We simulate this with a toy example: a sequence contains "signal" tokens (that should be remembered) and "noise" tokens (that should be ignored). The input-dependent $\Delta_t$ learns to open the gate for signal and close it for noise.

# %%
# Simulate selective gating: Mamba-style input-dependent Delta
T_sel = 40

# Create a sequence with "signal" (large values) and "noise" (small values)
np.random.seed(12)
is_signal = np.zeros(T_sel, dtype=bool)
signal_positions = [5, 6, 15, 16, 17, 30, 31]
is_signal[signal_positions] = True
x_seq = np.where(is_signal, np.random.uniform(2, 4, T_sel), np.random.randn(T_sel) * 0.3)
x_seq = x_seq.astype(np.float32)

# Fixed SSM (constant Delta)
delta_fixed = 0.1
a_scalar = 0.9
h_fixed = np.zeros(T_sel + 1, dtype=np.float32)
for t in range(T_sel):
    h_fixed[t + 1] = a_scalar * h_fixed[t] + delta_fixed * x_seq[t]

# Mamba-style (input-dependent Delta)
# Delta is large for signal, small for noise
delta_selective = np.where(is_signal, 0.8, 0.02).astype(np.float32)
h_selective = np.zeros(T_sel + 1, dtype=np.float32)
for t in range(T_sel):
    a_sel = np.exp(-delta_selective[t])  # discretized decay
    h_selective[t + 1] = a_sel * h_selective[t] + delta_selective[t] * x_seq[t]

fig, axes = plt.subplots(3, 1, figsize=(14, 8), sharex=True)

# Input sequence
colors_seq = ['#e74c3c' if s else '#bdc3c7' for s in is_signal]
axes[0].bar(range(T_sel), x_seq, color=colors_seq, edgecolor='k', linewidth=0.3)
axes[0].set_ylabel('$x_t$')
axes[0].set_title('Input Sequence (red = signal, gray = noise)', fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')

# Delta values
axes[1].bar(range(T_sel), delta_selective, color='#f39c12', edgecolor='k', linewidth=0.3,
            label='Mamba $\\Delta_t$ (selective)')
axes[1].axhline(delta_fixed, color='#3498db', linewidth=2, linestyle='--',
                label=f'Fixed $\\Delta = {delta_fixed}$')
axes[1].set_ylabel('$\\Delta_t$')
axes[1].set_title('Step Size (Gate Openness)', fontweight='bold')
axes[1].legend(); axes[1].grid(True, alpha=0.3, axis='y')

# Hidden states
axes[2].plot(range(T_sel + 1), h_fixed, '-o', color='#3498db', markersize=4,
             linewidth=2, label='Fixed SSM')
axes[2].plot(range(T_sel + 1), h_selective, '-s', color='#e74c3c', markersize=4,
             linewidth=2, label='Mamba (selective)')
axes[2].set_xlabel('Time step $t$'); axes[2].set_ylabel('$h_t$')
axes[2].set_title('Hidden State Evolution', fontweight='bold')
axes[2].legend(); axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Key insight:** The selective $\Delta_t$ acts as a **content-based gate**: when $\Delta_t$ is large, new information flows into the state; when $\Delta_t \approx 0$, the state ignores the input and retains its current value. This is analogous to the LSTM's input gate, but arises from the *discretization step size* of a continuous dynamical system.
#
# **Experiment:** Modify the `signal_positions` list. What happens if signal tokens are clustered together vs. spread apart? How does the selective state track multiple "memories" simultaneously?

# %% [markdown]
# ---
# # 5. Comparative Summary
#
# | Feature | Simple RNN | LSTM | Transformer (KV) | SSM / Mamba |
# |---|---|---|---|---|
# | **Memory type** | Fixed vector $\mathbf{h}_t$ | Fixed vector $(\mathbf{h}_t, \mathbf{c}_t)$ | Growing KV cache | Fixed vector $\mathbf{h}_t$ |
# | **Memory size** | $O(d)$ | $O(d)$ | $O(T \cdot d)$ | $O(d)$ |
# | **Per-step cost** | $O(d^2)$ | $O(d^2)$ | $O(T \cdot d)$ | $O(d^2)$ |
# | **Training** | Sequential ($O(Td^2)$) | Sequential ($O(Td^2)$) | Parallel ($O(T^2d)$) | Parallel (conv mode) or scan |
# | **Long-range memory** | Poor (vanishing gradient) | Good (forget gate) | Perfect (explicit storage) | Good (structured $A$) |
# | **Content-based retrieval** | No | Limited (gates) | Yes (attention) | Selective (Mamba) |
# | **Generation speed** | Fast ($O(d^2)$/step) | Fast ($O(d^2)$/step) | Slow ($O(Td)$/step) | Fast ($O(d^2)$/step) |
# | **Introduced** | 1990 | 1997 | 2017 | 2021/2023 |
#
# The evolution of memory architectures reflects a fundamental tension in sequence modeling:
#
# $$\text{compression} \quad \longleftrightarrow \quad \text{exact recall}.$$
#
# RNNs and SSMs compress aggressively (fixed-size state), gaining speed but losing fidelity. Transformers keep everything (KV cache), gaining perfect recall but paying in memory and compute. The ideal memory architecture — and whether a single architecture can dominate on both axes — remains an open research question.

# %% [markdown]
# ---
# # 6. Where to Go Next
#
# Topics we did not have time to cover:
#
# - **Multi-head attention as parallel memory banks**: each attention head can specialize in different types of retrieval patterns (local, syntactic, semantic).
# - **Sparse and linear attention**: methods like Linformer, Performer, and FlashAttention reduce the $O(T^2)$ cost of standard attention while retaining most of its recall ability.
# - **Memory-augmented networks**: Neural Turing Machines and Differentiable Neural Computers use an external read/write memory matrix with explicit addressing.
# - **Retrieval-augmented generation (RAG)**: instead of storing everything in parameters or a KV cache, retrieve relevant documents from an external database at inference time.
# - **Hybrid architectures**: Jamba (AI21, 2024) interleaves Transformer layers with Mamba layers, getting attention's recall for critical layers and Mamba's efficiency for the rest.

# %% [markdown]
# ---
# # 7. Exercises
#
# 1. **LSTM gradient flow.** Show that for the LSTM cell update $\mathbf{c}_t = \mathbf{f}_t \odot \mathbf{c}_{t-1} + \mathbf{i}_t \odot \tilde{\mathbf{c}}_t$, the gradient $\partial \mathbf{c}_T / \partial \mathbf{c}_t = \prod_{s=t+1}^T \text{diag}(\mathbf{f}_s)$. Explain why this product does not vanish when $\mathbf{f}_s \approx 1$, and contrast this with the simple RNN gradient product.
#
# 2. **KV cache memory budget.** A Transformer has $L = 32$ layers, $H = 32$ attention heads, key dimension $d_k = 128$, and uses 16-bit floating point. How many bytes does the KV cache require for a sequence of length $T = 8{,}192$? At what sequence length does the cache exceed 16 GB?
#
# 3. **SSM kernel decay.** For the scalar SSM $h_t = a \cdot h_{t-1} + b \cdot x_t$ with $|a| < 1$, show that the convolution kernel decays exponentially: $K_t = c \cdot a^t \cdot b$. What does this imply about the model's effective "memory horizon"? Compute the half-life of the kernel for $a = 0.99$ and $a = 0.9$.
#
# 4. **GRU vs. LSTM.** Replace `LSTM` with `GRU` in the "copy first bit" experiment and compare accuracy across sequence lengths. The GRU has fewer parameters (it merges forget and input gates). Does this help or hurt on this task? Explain.
#
# 5. **Selective attention.** Design a sequence task where the model must *ignore* certain tokens (e.g., noise tokens marked with a special flag) and attend only to signal tokens. Compare the performance of (a) an LSTM, (b) a Transformer, and (c) the selective SSM simulation from Section 4.3. Which architecture handles the selection most naturally?
